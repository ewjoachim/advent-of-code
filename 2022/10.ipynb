# %%
import boilerplate
l = boilerplate.get_input_lines(2022, 10).splitlines()

# %%
l = """addx 15
addx -11
addx 6
addx -3
addx 5
addx -1
addx -8
addx 13
addx 4
noop
addx -1
addx 5
addx -1
addx 5
addx -1
addx 5
addx -1
addx 5
addx -1
addx -35
addx 1
addx 24
addx -19
addx 1
addx 16
addx -11
noop
noop
addx 21
addx -15
noop
noop
addx -3
addx 9
addx 1
addx -3
addx 8
addx 1
addx 5
noop
noop
noop
noop
noop
addx -36
noop
addx 1
addx 7
noop
noop
noop
addx 2
addx 6
noop
noop
noop
noop
noop
addx 1
noop
noop
addx 7
addx 1
noop
addx -13
addx 13
addx 7
noop
addx 1
addx -33
noop
noop
noop
addx 2
noop
noop
noop
addx 8
noop
addx -1
addx 2
addx 1
noop
addx 17
addx -9
addx 1
addx 1
addx -3
addx 11
noop
noop
addx 1
noop
addx 1
noop
noop
addx -13
addx -19
addx 1
addx 3
addx 26
addx -30
addx 12
addx -1
addx 3
addx 1
noop
noop
noop
addx -9
addx 18
addx 1
addx 2
noop
noop
addx 9
noop
noop
noop
addx -1
addx 2
addx -37
addx 1
addx 3
noop
addx 15
addx -21
addx 22
addx -6
addx 1
noop
addx 2
addx 1
noop
addx -10
noop
noop
addx 20
addx 1
addx 2
addx 2
addx -6
addx -11
noop
noop
noop""".splitlines()

# %%
c = 0
x = 1
r = []

for e in l:
    c += 1
    if c % 40 == 20:
        r.append((x, c))
    e = e.split()
    if e[0] == "addx":
        c += 1
        if c % 40 == 20:
            r.append((x, c))
        x += int(e[1])

sum(x*c for x, c in r)
# Out:
# 13140

# %%
import itertools
x = 1
c = 0

def batched(iterable, n):
    it = iter(iterable)
    while (batch := list(itertools.islice(it, n))):
        yield batch

def draw(line, c, x):
    # print(line, c, x, "#" if x-1 <= c % 40 <= x+1 else ".")
    line.append("#" if x-1 <= (c-1) % 40 <= x+1 else ".")

line = []
for e in l:    
    c += 1
    draw(line, c, x)
    e = e.split()
    if e[0] == "addx":
        c += 1
        draw(line, c, x)
        x += int(e[1])
    
print("\n".join("".join(m for m in n) for n in batched(line, 40)))
# Out:
# ###..#..#..##...##...##..###..#..#.####.
# #..#.#..#.#..#.#..#.#..#.#..#.#..#....#.
# ###..#..#.#....#..#.#....###..#..#...#..
# #..#.#..#.#....####.#....#..#.#..#..#...
# #..#.#..#.#..#.#..#.#..#.#..#.#..#.#....
# ###...##...##..#..#..##..###...##..####.
